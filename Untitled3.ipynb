# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip
# !unzip bank.zip
# Out:
# --2025-06-19 05:11:29--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘bank.zip’
#
# bank.zip                [ <=>                ] 565.47K  --.-KB/s    in 0.1s
#
# 2025-06-19 05:11:29 (4.10 MB/s) - ‘bank.zip’ saved [579043]
#
# Archive:  bank.zip
#   inflating: bank-full.csv
#   inflating: bank-names.txt
#   inflating: bank.csv

# %%
import pandas as pd

df = pd.read_csv('bank-full.csv', sep=';')
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Check basic info
df.info()

# Look at target variable distribution
df['y'].value_counts()

# Preview your data
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB
# ...

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.isnull().sum()
# Out:
# age                    0
# balance                0
# day                    0
# duration               0
# campaign               0
# pdays                  0
# previous               0
# job_blue-collar        0
# job_entrepreneur       0
# job_housemaid          0
# job_management         0
# job_retired            0
# job_self-employed      0
# job_services           0
# job_student            0
# job_technician         0
# job_unemployed         0
# job_unknown            0
# marital_married        0
# marital_single         0
# education_secondary    0
# education_tertiary     0
# education_unknown      0
# default_yes            0
# housing_yes            0
# loan_yes               0
# contact_telephone      0
# contact_unknown        0
# month_aug              0
# month_dec              0
# month_feb              0
# month_jan              0
# month_jul              0
# month_jun              0
# month_mar              0
# month_may              0
# month_nov              0
# ...

# %%
X = df.drop('y_yes', axis=1)  # Assuming 'y' is converted into 'y_yes' column
y = df['y_yes']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8695652173913043
#
# Confusion Matrix:
#  [[1113   92]
#  [  85   67]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.93      0.92      0.93      1205
#         True       0.42      0.44      0.43       152
#
#     accuracy                           0.87      1357
#    macro avg       0.68      0.68      0.68      1357
# weighted avg       0.87      0.87      0.87      1357

# %%
plt.figure(figsize=(20,10))
plot_tree(model, feature_names=X.columns, class_names=["No", "Yes"], filled=True)
plt.show()

# %% [markdown]
# Task 3: Report – Decision Tree Classifier on Bank Marketing Dataset
# ✅ Objective:
# To predict whether a customer will subscribe to a term deposit (y = yes/no) using a Decision Tree Classifier on the Bank Marketing dataset.
#
# 🔍 Steps Performed:
# Loaded the Dataset: Used bank.csv from the UCI repository and loaded it using Pandas.
#
# Explored the Data: Observed data types, class distribution, and identified categorical features.
#
# Preprocessed:
#
# Converted categorical variables using one-hot encoding (pd.get_dummies()).
#
# Dropped one category to avoid dummy variable trap.
#
# Split Data:
#
# Used 70% for training, 30% for testing.
#
# Model Training:
#
# Used DecisionTreeClassifier from sklearn.
#
# Evaluation:
#
# Accuracy: (e.g. ~88%) (use your actual result)
#
# Confusion matrix and classification report show good performance.
#
# Visualization:
#
# Visualized the decision tree using plot_tree() for interpretation.
#
# 📈 Model Performance (example):
# Metric	Value
# Accuracy	88%
# Precision (Yes)	78%
# Recall (Yes)	66%
# F1-Score (Yes)	71%
#
# (Note: Use your actual model’s output)
#
# 💡 Insights:
# The model can effectively classify whether a customer will buy the product based on age, job, marital status, balance, etc.
#
# Feature encoding and preprocessing play a key role in model accuracy.
#
# Overfitting may occur with Decision Trees – can be controlled with pruning or setting max depth.
#
# ✅ Conclusion:
# The Decision Tree classifier gave decent accuracy and helped identify key customer features affecting term deposit subscription. Further improvement can be done using ensemble methods like Random Forest or tuning hyperparameters.
